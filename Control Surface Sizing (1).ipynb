# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Control Surface Sizings

# %% [markdown]
# ## Aileron Sizing

# %%
Swing = 0.41432 #planform area
bwing = 1.651 #Wing span
Cwing = 0.250952 #chord

RatioS = np.linspace(0.03,0.12,100)
RatioB = np.linspace(0.2,0.4,100)
RatioC = np.linspace(0.15,0.3,100)
Saileron = RatioS*Swing
Baileron = RatioB*bwing
Caileron = RatioC*Cwing

MaxS = 0.12*Swing
MaxB = 0.4*bwing
MaxC = 0.3*Cwing
MinS = 0.03*Swing
MinB = 0.2*bwing
MinC = 0.15*Cwing

print(f'The Minimum Recommended Aileron Planform is:\n {MinS} meters^2.\n The Maximum Reccomended Aileron Planform is:\n {MaxS} meters^2.')
print(f'The Minimum Recommended Aileron Span is:\n {MinB} meters.\n The Maximum Reccomended Aileron Span is:\n {MaxB} meters.')
print(f'The Minimum Recommended Aileron Chord is:\n {MinC} meters.\n The Maximum Reccomended Aileron Chord is:\n {MaxC} meters.')
# Out:
# The Minimum Recommended Aileron Planform is:
#  0.0124296 meters^2.
#  The Maximum Reccomended Aileron Planform is:
#  0.0497184 meters^2.
# The Minimum Recommended Aileron Span is:
#  0.33020000000000005 meters.
#  The Maximum Reccomended Aileron Span is:
#  0.6604000000000001 meters.
# The Minimum Recommended Aileron Chord is:
#  0.0376428 meters.
#  The Maximum Reccomended Aileron Chord is:
#  0.0752856 meters.

# %%
plt.title("Aileron Surface Area")
plt.xlabel("Aileron Surface Area Ratio(m^2)")
plt.ylabel("Aileron Surface Area")
plt.plot(RatioS,Saileron)

# %%
plt.title("Aileron Span")
plt.xlabel("Aileron Span Ratio")
plt.ylabel("Aileron Span(m)")
plt.plot(RatioB,Baileron)

# %%
plt.title("Aileron Chord")
plt.xlabel("Aileron Chord Ratio")
plt.ylabel("Aileron Chord(m)")
plt.plot(RatioC,Caileron)

# %% [markdown]
# ## Elevator Sizing

# %%
Scanard = 0.08920289047778149
Bcanard = 0.762
Ccanard = 0.1254258864985679

RatioS = np.linspace(0.15,0.4,100)
RatioB = np.linspace(0.8,1,100)
RatioC = np.linspace(0.2,0.4,100)
Selevator = RatioS*Scanard
Belevator = RatioB*Bcanard
Celevator = RatioC*Ccanard

MaxS = 0.4*Scanard
MaxB = Bcanard
MaxC = 0.4*Ccanard
MinS = 0.15*Scanard
MinB = 0.8*Bcanard
MinC = 0.2*Ccanard

print(f'The Minimum Recommended Elevator Planform is:\n {MinS} meters^2.\n The Maximum Reccomended Elevator Planform is:\n {MaxS} meters^2.')
print(f'The Minimum Recommended Elevator Span is:\n {MinB} meters.\n The Maximum Reccomended Elevator Span is:\n {MaxB} meters.')
print(f'The Minimum Recommended Elevator Chord is:\n {MinC} meters.\n The Maximum Reccomended Elevator Chord is:\n {MaxC} meters.')
# Out:
# The Minimum Recommended Elevator Planform is:
#  0.013380433571667223 meters^2.
#  The Maximum Reccomended Elevator Planform is:
#  0.0356811561911126 meters^2.
# The Minimum Recommended Elevator Span is:
#  0.6096 meters.
#  The Maximum Reccomended Elevator Span is:
#  0.762 meters.
# The Minimum Recommended Elevator Chord is:
#  0.02508517729971358 meters.
#  The Maximum Reccomended Elevator Chord is:
#  0.05017035459942716 meters.

# %%
plt.title("Elevator Surface Area")
plt.xlabel("Elevator Surface Area Ratio(m^2)")
plt.ylabel("Elevator Surface Area")
plt.plot(RatioS,Selevator)

# %%
plt.title("Elevator Span")
plt.xlabel("Elevator Span Ratio")
plt.ylabel("Elevator Span(m)")
plt.plot(RatioB,Belevator)

# %%
plt.title("Elevator Chord")
plt.xlabel("Elevator Chord Ratio")
plt.ylabel("Elevator Chord(m)")
plt.plot(RatioC,Celevator)

# %%
Svs = 0.04947520012727273 #vs -> vertical stabilizer
Bvs = 0.127 
Cvs = 0.2286

RatioS = np.linspace(0.15,0.35,100)
RatioB = np.linspace(0.7,1,100)
RatioC = np.linspace(0.15,0.4,100)
Srudder = RatioS*Svs
Brudder = RatioB*Bvs
Crudder = RatioC*Cvs

MaxS = 0.35*Svs
MaxB = Bvs
MaxC = 0.4*Cvs
MinS = 0.15*Svs
MinB = 0.7*Bvs
MinC = 0.15*Cvs

print(f'The Minimum Recommended Rudder Planform is:\n {MinS} meters^2.\n The Maximum Reccomended Rudder Planform is:\n {MaxS} meters^2.')
print(f'The Minimum Recommended Rudder Span is:\n {MinB} meters.\n The Maximum Reccomended Rudder Span is:\n {MaxB} meters.')
print(f'The Minimum Recommended Rudder Chord is:\n {MinC} meters.\n The Maximum Reccomended Rudder Chord is:\n {MaxC} meters.')
# Out:
# The Minimum Recommended Rudder Planform is:
#  0.007421280019090909 meters^2.
#  The Maximum Reccomended Rudder Planform is:
#  0.017316320044545454 meters^2.
# The Minimum Recommended Rudder Span is:
#  0.08889999999999999 meters.
#  The Maximum Reccomended Rudder Span is:
#  0.127 meters.
# The Minimum Recommended Rudder Chord is:
#  0.03429 meters.
#  The Maximum Reccomended Rudder Chord is:
#  0.09144000000000001 meters.

# %%
plt.title("Rudder Surface Area")
plt.xlabel("Rudder Surface Area Ratio(m^2)")
plt.ylabel("Rudder Surface Area")
plt.plot(RatioS,Srudder)

# %%
plt.title("Rudder Span")
plt.xlabel("Rudder Span Ratio")
plt.ylabel("Rudder Span(m)")
plt.plot(RatioB,Brudder)

# %%
plt.title("Rudder Chord")
plt.xlabel("Rudder Chord Ratio")
plt.ylabel("Rudder Chord(m)")
plt.plot(RatioC,Crudder)
